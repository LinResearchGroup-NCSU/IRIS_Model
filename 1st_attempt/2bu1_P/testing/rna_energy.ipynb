# %%
from modeller import *
# Get the sequence of the PDB file, and write to an alignment file
native_pdb = "2bu1.pdb"

e = environ()
m = model(e, file=native_pdb)
aln = alignment(e)
aln.append_model(m, align_codes=native_pdb)
aln.write(file=native_pdb + '.seq')
# Out:
# environ____W> The class 'environ' is deprecated; use 'Environ' instead
# model______W> The class 'model' is deprecated; use 'Model' instead
# pdbnam_____E> Filename for PDB code not found: 2bu1.pdb
#               Directories:
#               Extensions : :.atm:.pdb:.ent:.cif:.crd
#               (Also tried prepending 'pdb', looking for .Z, .gz, .bz2, .7z, .xz,
#               and trying PDB-style subdirectories - e.g. ab for pdb1abc.ent)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 6
#       3 native_pdb = "2bu1.pdb"
#       5 e = environ()
# ----> 6 m = model(e, file=native_pdb)
#       7 aln = alignment(e)
#       8 aln.append_model(m, align_codes=native_pdb)
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/modeller/model.py:523, in model.__init__(self, *args, **keys)
#     521 def __init__(self, *args, **keys):
# ...
